# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # World Population

# %%
url = 'https://raw.githubusercontent.com/mahmoudharding/exceed/main/data/2022_population.csv'
world = pd.read_csv('https://raw.githubusercontent.com/mahmoudharding/exceed/main/data/2022_population.csv')

# %% [markdown]
# Let's look further into the world data.

# %%
world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   iso_code           216 non-null    object
#  1   country            216 non-null    object
#  2   2022_last_updated  216 non-null    object
#  3   2020_population    216 non-null    object
#  4   area_sq_km         216 non-null    object
#  5   density_sq_km      216 non-null    object
#  6   growth_rate        216 non-null    object
#  7   world_%            216 non-null    object
#  8   rank               216 non-null    int64
# dtypes: int64(1), object(8)
# memory usage: 15.3+ KB

# %%
world.head(5)
# Out:
#   iso_code        country 2022_last_updated 2020_population area_sq_km  \
# 0      CHN          China     1,425,860,478   1,424,929,781  9,706,961
# 1      IND          India     1,420,588,493   1,396,387,127  3,287,590
# 2      USA  United States       338,846,055     335,942,003  9,372,610
# 3      IDN      Indonesia       276,124,105     271,857,970  1,904,569
# 4      PAK       Pakistan       237,444,363     227,196,741    881,912
#
#   density_sq_km growth_rate world_%  rank
# 0     147/sq_km       0.00%  17.88%     1
# 1     431/sq_km       0.68%  17.77%     2
# 2      36/sq_km       0.38%   4.24%     3
# 3     145/sq_km       0.64%   3.45%     4
# 4     267/sq_km       1.91%   2.96%     5

# %%
world.tail()
# Out:
#     iso_code           country 2022_last_updated 2020_population area_sq_km  \
# 211      MSR        Montserrat             4,390           4,500        102
# 212      FLK  Falkland Islands             3,780           3,747     12,173
# 213      NIU              Niue             1,934           1,942        260
# 214      TKL           Tokelau             1,871           1,827         12
# 215      VAT      Vatican City               510             520          1
#
#     density_sq_km growth_rate world_%  rank
# 211      43/sq_km      -0.61%   0.00%   230
# 212       0/sq_km       0.43%   0.00%   231
# 213       7/sq_km      -0.15%   0.00%   232
# 214     156/sq_km       1.19%   0.00%   233
# 215     510/sq_km      -0.20%   0.00%   234

# %%
world.set_index('country')
# Out:
#                  iso_code 2022_last_updated 2020_population area_sq_km  \
# country
# China                 CHN     1,425,860,478   1,424,929,781  9,706,961
# India                 IND     1,420,588,493   1,396,387,127  3,287,590
# United States         USA       338,846,055     335,942,003  9,372,610
# Indonesia             IDN       276,124,105     271,857,970  1,904,569
# Pakistan              PAK       237,444,363     227,196,741    881,912
# ...                   ...               ...             ...        ...
# Montserrat            MSR             4,390           4,500        102
# Falkland Islands      FLK             3,780           3,747     12,173
# Niue                  NIU             1,934           1,942        260
# Tokelau               TKL             1,871           1,827         12
# Vatican City          VAT               510             520          1
#
#                  density_sq_km growth_rate world_%  rank
# country
# ...

# %%
world_idx = world.set_index('country')

# %%
world_idx
# Out:
#                  iso_code 2022_last_updated 2020_population area_sq_km  \
# country
# China                 CHN     1,425,860,478   1,424,929,781  9,706,961
# India                 IND     1,420,588,493   1,396,387,127  3,287,590
# United States         USA       338,846,055     335,942,003  9,372,610
# Indonesia             IDN       276,124,105     271,857,970  1,904,569
# Pakistan              PAK       237,444,363     227,196,741    881,912
# ...                   ...               ...             ...        ...
# Montserrat            MSR             4,390           4,500        102
# Falkland Islands      FLK             3,780           3,747     12,173
# Niue                  NIU             1,934           1,942        260
# Tokelau               TKL             1,871           1,827         12
# Vatican City          VAT               510             520          1
#
#                  density_sq_km growth_rate world_%  rank
# country
# ...

# %%
world.iloc[1]
# Out:
# iso_code                       IND
# country                      India
# 2022_last_updated    1,420,588,493
# 2020_population      1,396,387,127
# area_sq_km               3,287,590
# density_sq_km            431/sq_km
# growth_rate                  0.68%
# world_%                     17.77%
# rank                             2
# Name: 1, dtype: object

# %%
world_idx.iloc[1]
# Out:
# iso_code                       IND
# 2022_last_updated    1,420,588,493
# 2020_population      1,396,387,127
# area_sq_km               3,287,590
# density_sq_km            431/sq_km
# growth_rate                  0.68%
# world_%                     17.77%
# rank                             2
# Name: India, dtype: object

# %%
world_idx.loc['India']
# Out:
# iso_code                       IND
# 2022_last_updated    1,420,588,493
# 2020_population      1,396,387,127
# area_sq_km               3,287,590
# density_sq_km            431/sq_km
# growth_rate                  0.68%
# world_%                     17.77%
# rank                             2
# Name: India, dtype: object

# %%
world.columns
# Out:
# Index(['iso_code', 'country', '2022_last_updated', '2020_population',
#        'area_sq_km', 'density_sq_km', 'growth_rate', 'world_%', 'rank'],
#       dtype='object')

# %%
world.loc[1, 'country']
# Out:
# 'India'

# %%
world.loc[1, ['iso_code', 'country']]
# Out:
# iso_code      IND
# country     India
# Name: 1, dtype: object

# %%
world.loc[[0,1], ['iso_code', 'country']]
# Out:
#   iso_code country
# 0      CHN   China
# 1      IND   India

# %%
world.loc[0:3, ['iso_code', 'country']]
# Out:
#   iso_code        country
# 0      CHN          China
# 1      IND          India
# 2      USA  United States
# 3      IDN      Indonesia

# %%
world.iloc[0:3, 0:4]
# Out:
#   iso_code        country 2022_last_updated 2020_population
# 0      CHN          China     1,425,860,478   1,424,929,781
# 1      IND          India     1,420,588,493   1,396,387,127
# 2      USA  United States       338,846,055     335,942,003

# %%
world.head(4)
# Out:
#   iso_code        country 2022_last_updated 2020_population area_sq_km  \
# 0      CHN          China     1,425,860,478   1,424,929,781  9,706,961
# 1      IND          India     1,420,588,493   1,396,387,127  3,287,590
# 2      USA  United States       338,846,055     335,942,003  9,372,610
# 3      IDN      Indonesia       276,124,105     271,857,970  1,904,569
#
#   density_sq_km growth_rate world_%  rank
# 0     147/sq_km       0.00%  17.88%     1
# 1     431/sq_km       0.68%  17.77%     2
# 2      36/sq_km       0.38%   4.24%     3
# 3     145/sq_km       0.64%   3.45%     4

# %%
world.shape
# Out:
# (216, 9)

# %%
np.random.randint(216)
# Out:
# 87

# %%
for i in range(10):
  row = np.random.randint(216)
  print(int(world.loc[row, 'density_sq_km'].replace('/sq_km', '')))
# Out:
# 28
# 326
# 603
# 84
# 449
# 4
# 196
# 260
# 65
# 33

# %%
world['density_num'] = world['density_sq_km'].str.replace('/sq_km', '').str.replace(',', '')

# %%
world
# Out:
#     iso_code           country 2022_last_updated 2020_population area_sq_km  \
# 0        CHN             China     1,425,860,478   1,424,929,781  9,706,961
# 1        IND             India     1,420,588,493   1,396,387,127  3,287,590
# 2        USA     United States       338,846,055     335,942,003  9,372,610
# 3        IDN         Indonesia       276,124,105     271,857,970  1,904,569
# 4        PAK          Pakistan       237,444,363     227,196,741    881,912
# ..       ...               ...               ...             ...        ...
# 211      MSR        Montserrat             4,390           4,500        102
# 212      FLK  Falkland Islands             3,780           3,747     12,173
# 213      NIU              Niue             1,934           1,942        260
# 214      TKL           Tokelau             1,871           1,827         12
# 215      VAT      Vatican City               510             520          1
#
#     density_sq_km growth_rate world_%  rank density_num
# ...

# %%
# world['density_num'].to_list()

# %%
#world = world.drop(['density_num'], axis=1)

# %%
world.columns
# Out:
# Index(['iso_code', 'country', '2022_last_updated', '2020_population',
#        'area_sq_km', 'density_sq_km', 'growth_rate', 'world_%', 'rank',
#        'density_num'],
#       dtype='object')

# %%
world['density_num'] = world['density_num'].astype('int')

# %%
med_density = np.median(world['density_num'])
med_density
# Out:
# 93.5

# %%
world['density_num'] > med_density
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 211    False
# 212    False
# 213    False
# 214     True
# 215     True
# Name: density_num, Length: 216, dtype: bool

# %%
world[world['density_num'] > med_density]
# Out:
#     iso_code           country 2022_last_updated 2020_population area_sq_km  \
# 0        CHN             China     1,425,860,478   1,424,929,781  9,706,961
# 1        IND             India     1,420,588,493   1,396,387,127  3,287,590
# 3        IDN         Indonesia       276,124,105     271,857,970  1,904,569
# 4        PAK          Pakistan       237,444,363     227,196,741    881,912
# 5        NGA           Nigeria       220,379,825     208,327,405    923,768
# ..       ...               ...               ...             ...        ...
# 208      NRU             Nauru            12,797          12,315         21
# 209      TUV            Tuvalu            11,441          11,069         26
# 210       BL  Saint Barthelemy            10,967          10,681         21
# 214      TKL           Tokelau             1,871           1,827         12
# 215      VAT      Vatican City               510             520          1
#
#     density_sq_km growth_rate world_%  rank  density_num
# ...

# %% [markdown]
# # Subsetting Data
#
# Uncover the factors that lead to employee attrition and explore important questions such as "show me a breakdown of distance from home by job role and attrition" or "compare average monthly income by education and attrition".
#
# **Note:** This is a fictional data set created by IBM data scientists.
#
# **Education**
# - 1 'Below College'
# - 2 'College'
# - 3 'Bachelor'
# - 4 'Master'
# - 5 'Doctor'
#
# **Environment Satisfaction**
# - 1 'Low'
# - 2 'Medium'
# - 3 'High'
# - 4 'Very High'
#
# **Job Involvement**
# - 1 'Low'
# - 2 'Medium'
# - 3 'High'
# - 4 'Very High'
#
# **Job Satisfaction**
# - 1 'Low'
# - 2 'Medium'
# - 3 'High'
# - 4 'Very High'
#
# **Performance Rating**
# - 1 'Low'
# - 2 'Good'
# - 3 'Excellent'
# - 4 'Outstanding'
#
# **Relationship Satisfaction**
# - 1 'Low'
# - 2 'Medium'
# - 3 'High'
# - 4 'Very High'
#
# **Work Life Balance**
# - 1 'Bad'
# - 2 'Good'
# - 3 'Better'
# - 4 'Best'

# %%
url = "https://raw.githubusercontent.com/mahmoudharding/exceed/main/data/HR-Employee-Attrition.csv"
hr = pd.read_csv(url)
hr
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# What types of questions do we have? What would you want to know? What do you think leads to attrition? Do we have right data?

# %%
hr.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
hr['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
hr['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
hr['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
pd.crosstab(hr['BusinessTravel'], hr['Attrition'])
# Out:
# Attrition           No  Yes
# BusinessTravel
# Non-Travel         138   12
# Travel_Frequently  208   69
# Travel_Rarely      887  156

# %%
pd.crosstab(hr['Attrition'], hr['BusinessTravel'])
# Out:
# BusinessTravel  Non-Travel  Travel_Frequently  Travel_Rarely
# Attrition
# No                     138                208            887
# Yes                     12                 69            156

# %%
hr['Age']
# Out:
# 0       41
# 1       49
# 2       37
# 3       33
# 4       27
#         ..
# 1465    36
# 1466    39
# 1467    27
# 1468    49
# 1469    34
# Name: Age, Length: 1470, dtype: int64

# %%
hr['Age'].hist();

# %%
np.sum(hr['Age'] >= 50)
# Out:
# 173

# %%
hr.shape[0]
# Out:
# 1470

# %%
np.sum(hr['Age'] >= 50)/hr.shape[0]
# Out:
# 0.11768707482993197

# %%
hr[hr['Age'] >= 50]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 6      59        No      Travel_Rarely       1324  Research & Development
# 18     53        No      Travel_Rarely       1219                   Sales
# 25     53        No      Travel_Rarely       1282  Research & Development
# 36     50       Yes      Travel_Rarely        869                   Sales
# 62     50        No      Travel_Rarely        989  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1434   52        No         Non-Travel        585                   Sales
# 1441   56        No         Non-Travel        667  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
hr[(hr['Age'] >= 50) & (hr['Attrition'] == 'No')]
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 6      59        No  Travel_Rarely       1324  Research & Development
# 18     53        No  Travel_Rarely       1219                   Sales
# 25     53        No  Travel_Rarely       1282  Research & Development
# 62     50        No  Travel_Rarely        989  Research & Development
# 63     59        No  Travel_Rarely       1435                   Sales
# ...   ...       ...            ...        ...                     ...
# 1397   54        No  Travel_Rarely        155  Research & Development
# 1401   55        No  Travel_Rarely        189         Human Resources
# 1406   54        No  Travel_Rarely        157  Research & Development
# 1434   52        No     Non-Travel        585                   Sales
# 1441   56        No     Non-Travel        667  Research & Development
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# ...

# %%
hr['BusinessTravel'].value_counts().plot.bar(rot = 0);
